# %% [markdown]
# <a href="https://colab.research.google.com/github/lagmagalhaes/EDA_Ifood/blob/main/Desafio_Ifood_Parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # Análise Exploratória de dados com Python

# %% [markdown]
# Este Dataset foi disponibilizado pelo curso EBA - Estatística do Básico ao Avançado para a análise de dados composto por clientes da empresa Ifood.

# %% [markdown]
# #Desafio Ifood - Parte 1
# Problema de Negócio:
#
# Como podemos aumentar o gasto médio dos clientes em nossa plataforma, utilizando as informações de perfil de clientes (renda, estado civil, filhos, etc.)?

# %%
# Importar Bibliotecas

# Importar bibioteca para manipulação de dados
import pandas as pd

# Importar biblioteca para operações matematicas
import numpy as np

# Importando biblotecas para auxiliar na visualização dos dados
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregar os dados e ler o arquivo.csv

df = pd.read_csv("/content/drive/MyDrive/mkt_data.csv")

# %%
# Mostrar o Arquivo
df
# Out:
#       Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0              0  58138.0        0         0       58       635         88
# 1              1  46344.0        1         1       38        11          1
# 2              2  71613.0        0         0       26       426         49
# 3              3  26646.0        1         0       26        11          4
# 4              4  58293.0        1         0       94       173         43
# ...          ...      ...      ...       ...      ...       ...        ...
# 2200        2200  61223.0        0         1       46       709         43
# 2201        2201  64014.0        2         1       56       406          0
# 2202        2202  56981.0        0         0       91       908         48
# 2203        2203  69245.0        0         1        8       428         30
# 2204        2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %% [markdown]
# Que dados temos? Linhas e colunas

# %%
# Que dados temos?
# Linhas e Colunas
df.shape
# Out:
# (2205, 44)

# %% [markdown]
# Verificamos que temos 44 colunas com total de 2205 linhas

# %% [markdown]
# # Colunas numéricas?

# %%
# Verificar os tipos de colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            2205 non-null   int64
#  1   Income                2205 non-null   float64
#  2   Kidhome               2205 non-null   int64
#  3   Teenhome              2205 non-null   int64
#  4   Recency               2205 non-null   int64
#  5   MntWines              2205 non-null   int64
#  6   MntFruits             2205 non-null   int64
#  7   MntMeatProducts       2205 non-null   int64
#  8   MntFishProducts       2205 non-null   int64
#  9   MntSweetProducts      2205 non-null   int64
#  10  MntGoldProds          2205 non-null   int64
#  11  NumDealsPurchases     2205 non-null   int64
#  12  NumWebPurchases       2205 non-null   int64
#  13  NumCatalogPurchases   2205 non-null   int64
#  14  NumStorePurchases     2205 non-null   int64
# ...

# %%
# Verificar quais são as colunas numéricas:
num = ['int64','float64']
df.select_dtypes(include=num).columns
# Out:
# Index(['Unnamed: 0', 'Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall', 'kids', 'expenses'],
#       dtype='object')

# %% [markdown]
# **Identificar e corrigirse houver valores duplicados e nulos**

# %%
# Verificar a existência de dados duplicados
duplicados = df.duplicated().sum()
print(duplicados)
# Out:
# 0

# %% [markdown]
# Não existem duplicados!!!

# %%
# Verificar se existem dados nulos
nulos = df.isnull().sum()
print(nulos)
# Out:
# Unnamed: 0                 0
# Income                     0
# Kidhome                    0
# Teenhome                   0
# Recency                    0
# MntWines                   0
# MntFruits                  0
# MntMeatProducts            0
# MntFishProducts            0
# MntSweetProducts           0
# MntGoldProds               0
# NumDealsPurchases          0
# NumWebPurchases            0
# NumCatalogPurchases        0
# NumStorePurchases          0
# NumWebVisitsMonth          0
# AcceptedCmp3               0
# AcceptedCmp4               0
# AcceptedCmp5               0
# AcceptedCmp1               0
# AcceptedCmp2               0
# Complain                   0
# Z_CostContact              0
# Z_Revenue                  0
# Response                   0
# Age                        0
# Customer_Days              0
# marital_Divorced        1975
# marital_Married         1351
# marital_Single          1728
# marital_Together        1637
# marital_Widow           2129
# ...

# %% [markdown]
# Temos colunas com valores nulos mas podem significar que os clientes não tem as caraterísticas das colunas em questão. Identificamos algo que é interessante para nós, pois os valores em falta dizem-nos muito. Por exemplo, a coluna marital_Single preenchida indica que este cliente é solteiro, logo não pode ter outro estado civil.

# %%
# Qual é a média, mediana, 25 percentil, 75 percentil, mínimo e máximo das colunas income, kids e expenses?
# Calculo das principais estatísticas das colunas numéricas de interesse.

df["Income" ].describe()
# Out:
# count      2205.000000
# mean      51622.094785
# std       20713.063826
# min        1730.000000
# 25%       35196.000000
# 50%       51287.000000
# 75%       68281.000000
# max      113734.000000
# Name: Income, dtype: float64

# %% [markdown]
# Qual é o maior salário encontrado na nossa base?
# - O Salário mais alto é de 113.734  e o mais baixo 1.730.
#
# Qual é a distribuição de salário na nossa base?                                                                      Temos clientes que ganham bem e outros que não ganham bem?
# - Com o histograma podemos verificar que a média (51.622) e a mediana (51.287) são bastante próximas, isso sugere que a distribuição do salário é relativamente simétrica, temos uma distribuição normal, onde há clientes que ganham bem e poucos clientes que não ganham bem .

# %%
# criamos uma coluna que define quem ganha bem, e quem não ganha bem, tendo como base o 3º quartil: 68281.0
df['Categoria_Salario'] = np.where(df['Income']>68281.0, "ganham_bem", "nao_ganham_bem")
df
# Out:
#       Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0              0  58138.0        0         0       58       635         88
# 1              1  46344.0        1         1       38        11          1
# 2              2  71613.0        0         0       26       426         49
# 3              3  26646.0        1         0       26        11          4
# 4              4  58293.0        1         0       94       173         43
# ...          ...      ...      ...       ...      ...       ...        ...
# 2200        2200  61223.0        0         1       46       709         43
# 2201        2201  64014.0        2         1       56       406          0
# 2202        2202  56981.0        0         0       91       908         48
# 2203        2203  69245.0        0         1        8       428         30
# 2204        2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %%
#Contagem de quem 'ganha_bem' e de quem 'não_ganha_bem'
df['Categoria_Salario'].value_counts()
# Out:
# Categoria_Salario
# nao_ganham_bem    1654
# ganham_bem         551
# Name: count, dtype: int64

# %% [markdown]
# Qual é a distribuição de salário na nossa base? Temos clientes que ganham muito bem e outros que não ganham muito bem?
# Diante do nosso histograma, é simetrico a distribuição de salários, a nossa média está em 51.6K e nossa mediana em 51.2K com pouca diferença, temos uma distribuição normal, onde há clientes que ganham melhor e poucos clientes que não ganham tão bem.

# %%
# Contagem dos valores de 'Categoria_Salario'
categoria_salario_counts = df['Categoria_Salario'].value_counts()

# Criação do gráfico de barras com quem 'ganha_bem' e de quem 'não_ganha_bem'
sns.barplot(x=categoria_salario_counts.index, y=categoria_salario_counts.values)
plt.xlabel('Categoria do Salário')
plt.ylabel('Valores')
plt.xticks(rotation=90)
plt.show()

# %%
 # Histograma do salário do cliente
df["Income"].hist()
# Out:
# <Axes: >

# %%
import plotly.express as px
fig = px.histogram(df, x="Income", nbins=15, title="Distribuição do Salário")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Boxplot Income
sns.boxplot(df["Income"])
# Out:
# <Axes: ylabel='Income'>

# %%
# Boxplot Distribuição do Salário
import plotly.express as px
fig = px.box(df, y="Income", title="Distribuição do Salário")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Com o boxplot Income e o Boxplot Distribuição do Salário verificamos que não existem outliers

# %%
# Calculo do coeficiente de variação
df["Income"].std()/df["Income"].mean()
# Out:
# 0.4012441554786958

# %%
df["Income"].skew()
# Out:
# 0.013164263414417078

# %% [markdown]
#  Pelo valores de skew e pelo boxplot, podemos dizer que apesar de não completamente normal, a curva se aproxima de uma normal.

# %% [markdown]
# **Que nivel de educação tem os nossos clientes**

# %%
# Gráfico de Barras com os niveis de educação
sns.countplot(x=df["education_level"])
# Out:
# <Axes: xlabel='education_level', ylabel='count'>

# %%
df.groupby(['education_level'])['Unnamed: 0'].count().reset_index()
# Out:
#   education_level  Unnamed: 0
# 0        2n Cycle         198
# 1           Basic          54
# 2      Graduation        1113
# 3          Master         364
# 4             PhD         476

# %%
# Criar um DataFrame a partir dos dados
data = {'education_level': ['2n Cycle', 'Basic', 'Graduation', 'Master', 'PhD'],
        'count': [198, 54, 1113, 364, 476]}
df_level = pd.DataFrame(data)

# Calcular a proporção
df_level['proportion'] = (df_level['count'] / df_level['count'].sum() * 100).round(2).astype(str) + '%'

print(df_level)
# Out:
#   education_level  count proportion
# 0        2n Cycle    198      8.98%
# 1           Basic     54      2.45%
# 2      Graduation   1113     50.48%
# 3          Master    364     16.51%
# 4             PhD    476     21.59%

# %% [markdown]
# A distribuição da educação é:
#
# Education_nivel2 - 9%
# Education_basic - 2%
# Education-Graduation - 50%
# Education_Master - 17%
# Education_PhD - 22%

# %% [markdown]
# **Qual é a distribuição dos nossos clientes em relação ao estado civil?**

# %%
# Quantos clientes temos em cada estado civil?
# Gráfico de Barras com o estado civil
sns.countplot(x=df["marital_status"])
# Out:
# <Axes: xlabel='marital_status', ylabel='count'>

# %%
df.groupby(['marital_status'])['Unnamed: 0'].count().reset_index()
# Out:
#   marital_status  Unnamed: 0
# 0       Divorced         230
# 1        Married         854
# 2         Single         477
# 3       Together         568
# 4          Widow          76

# %%
# Criar um DataFrame a partir dos dados
data = {'marital_status': ['Divorced', 'Married', 'Single', 'Together', 'Widow'],
        'count': [230, 854, 477, 568, 76]}
df_civil = pd.DataFrame(data)

# Calcular a proporção e arredondando para duas casas decimais
df_civil['proportion'] = round(df_civil['count'] / df_civil['count'].sum() * 100).round(2).astype(str) + '%'

print(df_civil)
# Out:
#   marital_status  count proportion
# 0       Divorced    230      10.0%
# 1        Married    854      39.0%
# 2         Single    477      22.0%
# 3       Together    568      26.0%
# 4          Widow     76       3.0%

# %% [markdown]
#  A distribuição dos clientes por estado civil:
#
# Viúvos(as) - 3%
# Divorciados(as) - 10%
# União de Fato - 26%
# Solteiros(as) - 22%
# Casados - 39%

# %% [markdown]
# #CORRELAÇÃO DOS DADOS
# **Qual é a relação do estado civil com números de filhos?**
# Será que as pessoas casadas têm um maior número de filhos?

# %%
df.groupby(["marital_status"])["kids"].describe()
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# marital_status
# Divorced        230.0  1.008696  0.741716  0.0  1.0  1.0  1.0  3.0
# Married         854.0  0.967213  0.732019  0.0  0.0  1.0  1.0  3.0
# Single          477.0  0.859539  0.777289  0.0  0.0  1.0  1.0  3.0
# Together        568.0  0.980634  0.749823  0.0  0.0  1.0  1.0  3.0
# Widow            76.0  0.881579  0.747745  0.0  0.0  1.0  1.0  2.0

# %%
# Calculo da Média de filhos por estado civil
df.groupby("marital_status")["kids"].mean()
# Out:
# marital_status
# Divorced    1.008696
# Married     0.967213
# Single      0.859539
# Together    0.980634
# Widow       0.881579
# Name: kids, dtype: float64

# %% [markdown]
# Com as médias obtidas não podemos afirmar se há relacão do estado civil com números de filhos.

# %%
sns.boxplot(x='marital_status', y='kids', data=df)
# Out:
# <Axes: xlabel='marital_status', ylabel='kids'>

# %% [markdown]
#  **Qual a relação entre as pessoas gastarem mais ou menos na plataforma quando se têm filhos?**

# %%
sns.boxplot(x='kids', y='expenses', data=df)
# Out:
# <Axes: xlabel='kids', ylabel='expenses'>

# %%
#Calculo da Média de Gastos
df.groupby("kids")["expenses"].mean()
# Out:
# kids
# 0    1041.207006
# 1     434.530576
# 2     221.568675
# 3     237.380000
# Name: expenses, dtype: float64

# %%
# Calculo da Mediana de Gastos
df.groupby("kids")["expenses"].median()
# Out:
# kids
# 0    1106.5
# 1     264.0
# 2      84.0
# 3      62.0
# Name: expenses, dtype: float64

# %% [markdown]
# Podemos afirmar que quanto mais filhos menos gastam na nossa plataforma. A média de gastos quando se têm 3 filhos é de 237,38, quando se tem 2 filhos cai um pouco para 221,57 e quando  se tem um filho a média sobe para 434,53 e quando não há filhos a média é de 1000.

# %%
df.groupby(['kids'])['expenses'].describe()
# Out:
#        count         mean         std  min     25%     50%      75%     max
# kids
# 0      628.0  1041.207006  625.734894  5.0  546.00  1106.5  1505.50  2491.0
# 1     1112.0   434.530576  452.606603  4.0   50.00   264.0   762.25  2036.0
# 2      415.0   221.568675  290.259678  8.0   39.00    84.0   296.50  1627.0
# 3       50.0   237.380000  390.174157  6.0   28.25    62.0   254.00  1601.0

# %% [markdown]
# Podemos ver que os clientes com mais filhos gastam menos em relação aos clientes com menos filhos ou nenhum filho, a média de gasto quando se têm 3 filhos é de 237,38, quando se tem 2 filhos desce ligeiramente  para 221,57 e quando se tem apenas um filho a média sobe para 434,53 e quando não há filhos a média é de 1000.

# %% [markdown]
# **Cliente que têm um maior salário gastam mais?**

# %%
# Histograma para analisar correlação se maior salário gastam mais
sns.histplot(x='Income', y='expenses', data=df)
# Out:
# <Axes: xlabel='Income', ylabel='expenses'>

# %%
#cálcular a correlação de person entre as duas variáveis
correlação = df["expenses"].corr(df['Income']) * 100
print(f'A correlação entre expenses e Income: {correlação:.2f}%')
# Out:
# A correlação entre expenses e Income: 82.31%

# %% [markdown]
# Como vemos no histograma tem crescimento para cima, indica uma correlação é positiva, mas para confirmar calculamos a correlação entre as variáveis que teve o resultado de  0,8230, ou seja, bastante próximo de 1.. Isto indica que as variáveis tem uma forte correlação direta, quanto mais o cliente ganha, mais gasta na aplicação

# %% [markdown]
# **Verificação de como foi a aceitação da campanha do marketing em relação aos nossos clientes**

# %%
# Fazemos o boxplot para identificar se há correlação entre aceitação maior e gastos.
sns.boxplot(x='AcceptedCmpOverall', y='expenses', data=df)
# Out:
# <Axes: xlabel='AcceptedCmpOverall', ylabel='expenses'>

# %%
#cálcular a média de gasto conforme a aceitação geral
df.groupby(['AcceptedCmpOverall'])['expenses'].mean()
# Out:
# AcceptedCmpOverall
# 0     440.551803
# 1     855.767081
# 2    1341.950617
# 3    1615.840909
# 4    1445.454545
# Name: expenses, dtype: float64

# %%
#cálcular a correlação de person em relação da aceitação geral com aumento de gastos
df['AcceptedCmpOverall'].corr(df['expenses']) * 100
print(f'A correlação entre AcceptedCmpOveral e expenses: {correlação:.2f}%')
# Out:
# A correlação entre AcceptedCmpOveral e expenses: 82.31%

# %%
 #contar a quantidade de aceitação geral por estado civil
df.groupby(['marital_status'])['AcceptedCmpOverall'].count()
# Out:
# marital_status
# Divorced    230
# Married     854
# Single      477
# Together    568
# Widow        76
# Name: AcceptedCmpOverall, dtype: int64

# %%
 #contar a aceitação geral por estado civil e quantidade de filhos
df.groupby(['marital_status', 'kids'])['AcceptedCmpOverall'].count()
# Out:
# marital_status  kids
# Divorced        0        57
#                 1       119
#                 2        49
#                 3         5
# Married         0       227
#                 1       444
#                 2       167
#                 3        16
# Single          0       168
#                 1       222
#                 2        73
#                 3        14
# Together        0       150
#                 1       294
#                 2       109
#                 3        15
# Widow           0        26
#                 1        33
#                 2        17
# Name: AcceptedCmpOverall, dtype: int64

# %% [markdown]
# É possível afirmar de forma moderada que os clientes com maior aceitação das campanhas tendem a aumentar os seus gastos. Em outras palavras, existe uma correlação positiva moderada nesse sentido, o que sugere que campanhas eficazes podem ser uma estratégia importante para incentivar o aumento do consumo por parte dos clientes.

# %% [markdown]
# #Desafio Ifood - Parte 2
#
# O conjunto de dados é composto por clientes da empresa Ifood com dados sobre:
#
#
# - Perfis de clientes
# - Preferências do produto
# - Sucessos/fracassos da campanha
# - Desempenho do canal

# %% [markdown]
# Suponha que estamos tentar atrair mais clientes. Na análise de dados anterior, vimos que os clientes sem filhos gastam mais que os clientes com filhos. A equipa de marketing pensou em fazer campanhas direcionadas ao grupo de pessoas com filho (independente da quantidade), porém precisamos comprovar se de fato as médias de gastos dos grupos é diferente. Portanto:
#
# **Agrupar todas os clientes que tem filhos em um grupo chamado "com filhos" e fazer uma comparação da média de gastos de clientes sem filhos e clientes com filhos.**

# %%
# Criando coluna de despesas dos que tem filhos

df['expenses_com_kids'] = df[df['kids']!=0]['expenses']

# Criando coluna de despesas dos que não tem filhos

df['expenses_sem_kids'] = df[df['kids']== 0]['expenses']

# %%
# Mostrar o Arquivo
df
# Out:
#       Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0              0  58138.0        0         0       58       635         88
# 1              1  46344.0        1         1       38        11          1
# 2              2  71613.0        0         0       26       426         49
# 3              3  26646.0        1         0       26        11          4
# 4              4  58293.0        1         0       94       173         43
# ...          ...      ...      ...       ...      ...       ...        ...
# 2200        2200  61223.0        0         1       46       709         43
# 2201        2201  64014.0        2         1       56       406          0
# 2202        2202  56981.0        0         0       91       908         48
# 2203        2203  69245.0        0         1        8       428         30
# 2204        2204  52869.0        1         1       40        84          3
#
# ...

# %% [markdown]
# Aqui não conhecemos o desvio padrão populacional, apenas conseguimos o desvio padrão e média das amostras. Vamos verificar a quantidade de dados de cada uma das amostras para verificar se podemos aplicar o Teorema do Limite Central.

# %%
# Contar o número de valores não nulos na coluna "expenses_com_filhos".
df['expenses_com_kids'].count()
# Out:
# 1577

# %%
# Contar o número de valores não nulos na coluna "expenses_sem_filhos".
df['expenses_sem_kids'].count()
# Out:
# 628

# %% [markdown]
# Temos um grande número de amostras, pelo que o ***teorema do limite central*** assegura que a distribuição das médias das amostras se aproxima de uma distribuição normal. Assim, vamos proceder à aplicação do ***teste T***.

# %% [markdown]
# Ho: as médias de gastos são iguais.
#
# Ha: as médias de gastos são diferentes.
#
# Vamos usar 95% de confiança

# %%
from scipy import stats
import numpy as np

# Suponha que df é o DataFrame com as colunas expenses_com_kids e expenses_sem_kids

# Removendo valores NaN e obtendo as amostras

expenses_com_kids = df['expenses_com_kids'].dropna()
expenses_sem_kids = df['expenses_sem_kids'].dropna()

# Calculando o teste t
t_stat, p_value = stats.ttest_ind(expenses_com_kids, expenses_sem_kids)

# Exibindo os resultados
print("Estatística t:", t_stat)
print("Valor-p:", p_value)
# Out:
# Estatística t: -28.902593571564687
# Valor-p: 5.171525024868465e-156

# %% [markdown]
# O p-value é muito menor que 0.05, logo rejeitamos a hipotese nula e podemos afirmar ao nível de 95% de confiança que houve diferença na média de gastos entre os grupos que tem filhos e os que não tem filhos.

# %%
#calcular a média para cada grupo
print("Médias expenses com filhos:", expenses_com_kids.mean().round(2))
print("Médias expenses sem filhos:", expenses_sem_kids.mean().round(2))
# Out:
# Médias expenses com filhos: 372.24
# Médias expenses sem filhos: 1041.21

# %% [markdown]
# Conseguimos ver claramente que a média de gastos para os clientes com filhos é claramente menor dque os clientes sem filhos.

# %% [markdown]
# **Agora, vamos comparar os grupos de pessoas com filhos. O time de marketing nos perdiu para verificar se há diferenças de gastos em quem tem 1, 2, 3 ou mais filhos para que eles possam afunilar mais ainda a campanha. Para isso, vamos analisar os dados:**

# %%
# Verificar o tamanho de cada amostra

df['kids'].value_counts()
# Out:
# kids
# 1    1112
# 0     628
# 2     415
# 3      50
# Name: count, dtype: int64

# %%
df.groupby(["kids"]).expenses.mean().round(2)
# Out:
# kids
# 0    1041.21
# 1     434.53
# 2     221.57
# 3     237.38
# Name: expenses, dtype: float64

# %% [markdown]
# Podemos constatar que o nosso objetivo é analisar se o número de filhos tem impacto na média de despesas e comparar os grupos.
# Para isso, vamos utilizar a  ANOVA 1 fator. As permissas para a ANOVA são:
# Premissas:
#
# Amostras aleatorias;
# - Grupos independentes;
# - A variáveis dependente é contínua
# - A variavel independente é categorica
# os dados devem seguir uma distribuição normal, ou cada grupo deve ter mais de 15 ou 20 observações
# - Os grupos devem ter variaçoes aproximadamente iguais.
#
# Ho: Não há diferenças na média de gastos entre os grupos.
#
# Ha: Nem todas as médias são iguais.

# %% [markdown]
# **Antes de realizar o teste ANOVA, é necessário verificar se todas as variâncias são iguais:**

# %%
# Eliminar os valores nulos para fazer os testes

com_um_filho = df[df['kids'] == 1]['expenses'].dropna()
com_dois_filhos = df[df['kids'] == 2]['expenses'].dropna()
com_tres_filhos = df[df['kids'] == 3]['expenses'].dropna()

# %%
# Vamos usar o teste de Barlett para testar se as variâncias são iguais ou diferentes

import scipy.stats as stats

stats.bartlett(com_um_filho, com_dois_filhos, com_tres_filhos)
# Out:
# BartlettResult(statistic=102.21719770243517, pvalue=6.365280420300725e-23)

# %% [markdown]
# O p_value é menor que 0.05, logo rejeitamos a hipotese nula e aceitamos que pelo menos uma das amostras possui variancia diferente. Portanto, poderiamos usar a **ANOVA de Welch**

# %%
# !pip install pingouin
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import pingouin as pg

com_filhos = df[df['kids'] != 0]

pg.welch_anova(dv='expenses',between='kids',data=com_filhos)
# Out:
#   Source  ddof1       ddof2          F         p-unc       np2
# 0   kids      2  132.724442  59.721904  3.178541e-19  0.051464

# %% [markdown]
# O p_valor é menor do que alpha (0.05), portanto, rejeitamos H0 e concluimos que a 95% de confiança que as médias de gastos entre os grupos não são iguais.

# %% [markdown]
# Agora, vamos usar um teste **Post Hoc (Games-Howell)** para descobrir qual dos pares não são iguais. Lembrando que esses dados violam a aproximação de dados para normalidade e as amostras não tem variancias iguais. Neste caso não podemos usar Tukey.

# %%
# Utilizar o teste games Howell

pg.pairwise_gameshowell(dv='expenses',between='kids',data=com_filhos)
# Out:
#    A  B     mean(A)     mean(B)        diff         se          T  \
# 0  1  2  434.530576  221.568675  212.961901  19.678256  10.822194
# 1  1  3  434.530576  237.380000  197.150576  56.823741   3.469511
# 2  2  3  221.568675  237.380000  -15.811325  56.988869  -0.277446
#
#             df          pval    hedges
# 0  1152.588538  2.596812e-13  0.513077
# 1    55.099957  2.888048e-03  0.437688
# 2    55.722906  9.584865e-01 -0.052201

# %% [markdown]
# Apenas quando p-valor for maior do que 5e-02 aceitamos H0 (médias iguais). Logo, todas as médias são consideradas diferentes, exceto a 2-3.
#
# Verificamos que os grupos dos clientes com 1 filho e 2 filhos têm médias diferentes, uma vez que o p_valor é inferior a 0,05, permitindo-nos rejeitar a hipótese nula. O mesmo acontece com o grupo dos clientes com 1 filho e 3 filhos. No entanto, para o grupo de pessoas com 2 filhos e 3 filhos, o p_valor é superior a 0,05, pelo que não podemos rejeitar a hipótese nula.
#
# Sendo assim, os gastos médios dos grupos com 2 e 3 filhos são estatisticamente iguais. No entanto, verificam-se diferenças significativas nas médias dos restantes grupos. Consequentemente, a equipa de marketing pode direcionar os seus esforços para os grupos familiares com 2 ou 3 filhos
